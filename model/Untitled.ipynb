# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
data = np.load('../summary/1/allocation/3000_test.npy')
x = list(range(data.shape[0]))
for i in range(7):
    y = data[:,i]
    plt.plot(x,y,label=str(i))
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-ad92979b1308> in <module>()
#       3 get_ipython().magic('matplotlib inline')
#       4 import pandas as pd
# ----> 5 data = np.load('../summary/1/allocation/3000_test.npy')
#       6 x = list(range(data.shape[0]))
#       7 for i in range(7):
#
# /usr/local/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     368     own_fid = False
#     369     if isinstance(file, basestring):
# --> 370         fid = open(file, "rb")
#     371         own_fid = True
#     372     elif is_pathlib_path(file):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../summary/1/allocation/3000_test.npy'

# %%
import data_provider as dp
import matplotlib.pyplot as plt
# %matplotlib inline
c = dp.futuresData()
c.loadData_moreday0607(False)
c_test = dp.futuresData()
c_test.loadData_moreday0607(False)
c_test.mPrice = c_test.mPrice - c_test.mPrice[0,:] + 1
price = c_test.mPrice
start = 0
end = 94
x = list(range(start,end))
for i in range(7):
#     if i==4 or i==3 :continue
    y = price[start:end,i]
    plt.plot(x,y,label=str(i))
plt.legend()
plt.show()
# Out:
# [A3C_data]Loading data from data/moreday0607.csv ...
# [A3C_data]Successfully loaded 600 data
# [A3C_data]Loading data from data/moreday0607.csv ...
# [A3C_data]Successfully loaded 600 data
